# %%
import pandas as pd
import numpy as np
import folium
from sklearn.cluster import KMeans
import requests
# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors
import json

# %%
with open('Parks Zones.geojson', 'r') as file_handle:    
    park_zones = json.load(file_handle)

# %%
list_of_parks = [i['properties']['propname'] for i in park_zones['features']]

# %%
len(list_of_parks)
# Out:
# 588

# %%
len(list(set(list_of_parks)))
# Out:
# 103

# %% [markdown]
# ## Create a df with names of parks and center coordinates

# %%
parks_list_for_df = []
for item in park_zones['features']:
    park_name = item['properties']['propname']
    acres = item['properties']['acres']
    location = item['properties']['location']
    zipcode = item['properties']['zipcode']
    tmp_coord = np.array(item['geometry']['coordinates'][0][0])
#     print(tmp_coord.shape)
    coordinates = np.sum(tmp_coord, axis =0) / tmp_coord.shape[0]
    latitude= coordinates[1]
    longitude = coordinates[0]
#     print(coordinates.shape)
    parks_list_for_df.append([park_name, location, acres, zipcode, latitude, longitude])

# %%
parks_df = pd.DataFrame(parks_list_for_df, columns=['Park_name', 'Address', 'Acres', 'Zipcode', 'Latitude', 'Longitude'])

# %%
parks_df = parks_df[parks_df['Park_name'].notna()]

# %%
parks_df['Acres'].fillna(np.Inf, inplace=True)

# %%
parks_df['Acres'] = parks_df['Acres'].astype(float)

# %%
#We want to tackle smaller parks, since this is where there's a higher probability of not having an established coffee shop

# %%
five_smallest = parks_df[['Park_name','Acres']].groupby('Park_name').sum().sort_values(by='Acres').nsmallest(n=5,columns=['Acres'])

# %%
five_smallest_list = five_smallest.index.tolist()

# %%
#Get the average latitude/longitude per park to identify a "central point"
parks_to_check = parks_df[['Park_name', 'Latitude', 'Longitude']].groupby('Park_name').agg(np.mean).reset_index()

# %%
parks_df['To sample'] = parks_df['Park_name'].apply(lambda x: x in five_smallest_list)

# %%
parks_sample = parks_df[parks_df['To sample']]

# %%
parks_sample.head()
# Out:
#                    Park_name                        Address     Acres Zipcode  \
# 30         Little Red Square  Bleecker St & Ave Of Americas  0.038576   10012
# 78            O'Connors Tail               Broadway & 78 St  0.148286   11373
# 327        Park Avenue Malls       Park Ave, E96 St, E97 St  0.237877   10029
# 530  Hempstead Bench Stretch               225 St & 104 Ave  0.381692   11429
# 579       Downing Playground       Bleecker And Downing Sts  0.052782   10014
#
#       Latitude  Longitude  To sample
# 30   40.729376 -74.002105       True
# 78   40.744900 -73.887671       True
# 327  40.786897 -73.952294       True
# 530  40.710615 -73.729662       True
# 579  40.729820 -74.002387       True

# %% [markdown]
# ## Foursquare login details, removed before committing the notebook

# %%
CLIENT_ID = '3JHGGHSJUJT3VSUZXAZ2M2X1TDQFT1R10RFJJBN02R2SJ34M' # your Foursquare ID
CLIENT_SECRET = 'D4D4J0RPXPVJ5JHQXI5HVMPJQVI54LCPNT4D4AIUBJLHWSGD' # your Foursquare Secret
VERSION = '20190221' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: 3JHGGHSJUJT3VSUZXAZ2M2X1TDQFT1R10RFJJBN02R2SJ34M
# CLIENT_SECRET:D4D4J0RPXPVJ5JHQXI5HVMPJQVI54LCPNT4D4AIUBJLHWSGD

# %%
import pdb

# %%
def get_summary_of_stats_by_venue_id(venue_id):
    url = 'https://api.foursquare.com/v2/venues/{}?&client_id={}&client_secret={}&v={}'.format(
            venue_id,
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION)
    results = requests.get(url).json()["response"]
    venue_stats=[]
    if 'venue' in results.keys():
        for item_to_retrieve in ['rating', 'likes']:
            if item_to_retrieve not in results['venue'].keys():
                venue_stats.append(None)
            else:
                if item_to_retrieve == 'likes':
                    venue_stats.append(results['venue'][item_to_retrieve]['count'])
                else:
                    venue_stats.append(results['venue'][item_to_retrieve])
    else:
        venue_stats = [None, None]
    return venue_stats

# %% [markdown]
# ## Find nearby venues to a specific point on map

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500, categories_list=[]):
    radius = 500
    LIMIT = 100
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)  
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        #check if category within categories list, if any provided
        if categories_list:
            filtered_results = [result for result in results if result['venue']['categories'][0]['name'] in categories_list]
            results = filtered_results
        
        # return only relevant information for each nearby venue that has a rating
        venues_list.append([
            (
            name, 
            lat, 
            lng, 
            v['venue']['name'],
            v['venue']['id'],
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],
            v['venue']['categories'][0]['name'])
            for v in results ])
    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Park_name',
                  'Park Latitude', 
                  'Park Longitude', 
                  'Venue',
                  'Venue ID',
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
venues_nearby_df = getNearbyVenues(names=parks_sample['Park_name'], latitudes=parks_sample['Latitude'], longitudes=parks_sample['Longitude'], categories_list=['Coffee Shop', 'Café'])
# Out:
# Little Red Square
# O'Connors Tail
# Park Avenue Malls
# Hempstead Bench Stretch
# Downing Playground

# %%
venues_nearby_df
# Out:
#              Park_name  Park Latitude  Park Longitude  \
# 0    Little Red Square      40.729376      -74.002105
# 1    Little Red Square      40.729376      -74.002105
# 2    Little Red Square      40.729376      -74.002105
# 3    Little Red Square      40.729376      -74.002105
# 4    Little Red Square      40.729376      -74.002105
# 5       O'Connors Tail      40.744900      -73.887671
# 6    Park Avenue Malls      40.786897      -73.952294
# 7    Park Avenue Malls      40.786897      -73.952294
# 8    Park Avenue Malls      40.786897      -73.952294
# 9    Park Avenue Malls      40.786897      -73.952294
# 10  Downing Playground      40.729820      -74.002387
# 11  Downing Playground      40.729820      -74.002387
# 12  Downing Playground      40.729820      -74.002387
# 13  Downing Playground      40.729820      -74.002387
#
#                        Venue                  Venue ID  Venue Latitude  \
# 0                     Banter  589c7ca37b43b441e3ac3ef8       40.727959
# 1   Porto Rico Importing Co.  3fd66200f964a52059e61ee3       40.729483
# 2             Bluestone Lane  56acef5b498ec8e203a43bb7       40.730009
# 3     Summers Juice & Coffee  562d0e34498e348022841311       40.727640
# 4                west~bourne  5a1ed5c967e5f2347f77664b       40.726932
# 5             969 nyc coffee  5803cb7738fa2724aedd7d02       40.747744
# 6                    Da Capo  5328a418498e4be839240b62       40.787679
# 7      Bonjour Crêpes & Wine  529ba40e11d2e2aa2818ad9b       40.784543
# 8           Frenchy Cafe NYC  5a772c1625ecca5ea8cd01cd       40.789803
# 9     Corner Cafe and Bakery  49f0b229f964a52048691fe3       40.782785
# 10  Porto Rico Importing Co.  3fd66200f964a52059e61ee3       40.729483
# 11            Bluestone Lane  56acef5b498ec8e203a43bb7       40.730009
# 12                    Banter  589c7ca37b43b441e3ac3ef8       40.727959
# 13    Summers Juice & Coffee  562d0e34498e348022841311       40.727640
#
#     Venue Longitude Venue Category
# 0        -74.001205           Café
# 1        -74.001722    Coffee Shop
# 2        -74.002855           Café
# 3        -74.000316           Café
# 4        -74.002022           Café
# 5        -73.885830           Café
# 6        -73.953899           Café
# 7        -73.951990           Café
# 8        -73.948164           Café
# 9        -73.950983           Café
# 10       -74.001722    Coffee Shop
# 11       -74.002855           Café
# 12       -74.001205           Café
# 13       -74.000316           Café

# %%
#Use the overall park list to try and identify what other venues are popular next to the "best performing" coffee shops
venues_nearby_all_parks_df = getNearbyVenues(names=parks_to_check['Park_name'], latitudes=parks_to_check['Latitude'], longitudes=parks_to_check['Longitude'])
# Out:
# Alley Pond Park
# Aqueduct Walk
# Astoria Park
# Baisley Pond Park
# Battery Park
# Belt Parkway/Shore Parkway
# Bloomingdale Park
# Blue Heron Park Preserve
# Broadway Malls
# Bronx & Pelham Pkwy(2.5 Miles)
# Bronx Park
# Brooklyn Bridge Park
# Brookville Park
# Canarsie Park
# Carl Schurz Park
# Central Park
# Claremont Park
# Clove Lakes Park
# Coney Island Beach & Boardwalk
# Coney Island Boat Basin
# Conference House Park
# Crocheron Park
# Crotona Park
# Crotona Parkway Malls
# Cunningham Park
# Downing Playground
# Dreier-Offerman Park
# Dyker Beach Park
# East River Esplanade
# East River Waterfront Esplanade
# Eastern Parkway
# Emile Cavanaugh Triangle
# FDR Boardwalk & Beach
# Ferry Point Park
# Flushing Meadows Park
# Forest Park
# Fort Greene Park
# Fort Totten Park
# Fort Tryon Park
# Fort Washington Park
# Franz Sigel Park
# Fresh Kills Park
# Geo Soilan Pk-Battery Pk City
# Goodhue Park
# Grand Central Parkway
# Great Kills Park
# Harlem River Park
# Hempstead Bench Stretch
# Herman A Macneil Park
# Highbridge Park
# Highland Park
# Idlewild Park
# Inwood Hill Park
# Isham Park
# John Mullaly Park
# John V. Lindsay - East River Park
# Juniper Valley Park
# Kissena Corridor Park
# Kissena Park
# Leon S Kaiser Park
# Lincoln Terrace Park / Arthur S. Somers
# Little Bay Park
# Little Red Square
# Macombs Dam Park
# Manhattan Beach Park
# Marcus Garvey Memorial Park
# Marine Park
# McCarren Park
# Morningside Park
# Mosholu Parkway (2.Miles)
# O'Connors Tail
# Ocean Parkway (5.5 Miles)
# Park (Arden Heights Woods)
# Park Avenue Malls
# Pelham Bay Park
# Powell'S Cove Park
# Prospect Park
# Pugsley Creek Park
# Randalls Island
# Red Hook Recreation Area
# Riverdale Park
# Riverside Park
# Riverside Park South
# Rockaway Beach & Boardwalk
# Rockaway Freeway
# Roy Wilkins-Southern Queens Pk
# S.I. Greenbelt
# Seton Falls Park
# Shore Park And Parkway
# Silver Lake Park
# Soundview Park
# Spring Creek Park
# St Mary's Park
# St Nicholas Park
# Starlight Park
# Steeplechase Park
# Sutton Place Pk
# The High Line
# Van Cortlandt Park
# Wards Island
# Washington Square Park
# Wolfe's Pond Park

# %%
parks_with_caffes = venues_nearby_all_parks_df[venues_nearby_all_parks_df.apply(lambda x: ('Coffee' in x['Venue Category']) | ('Caf' in x['Venue Category']), axis=1)]['Park_name'].unique()

# %%
venues_nearby_all_parks_df['Park_with_cafe'] = venues_nearby_all_parks_df.apply(lambda x: x['Park_name'] in parks_with_caffes, axis=1)

# %%
venues_nearby_all_parks_df
# Out:
#                    Park_name  Park Latitude  Park Longitude  \
# 0            Alley Pond Park      40.748450      -73.745363
# 1            Alley Pond Park      40.748450      -73.745363
# 2            Alley Pond Park      40.748450      -73.745363
# 3            Alley Pond Park      40.748450      -73.745363
# 4            Alley Pond Park      40.748450      -73.745363
# 5              Aqueduct Walk      40.858241      -73.907932
# 6              Aqueduct Walk      40.858241      -73.907932
# 7              Aqueduct Walk      40.858241      -73.907932
# 8              Aqueduct Walk      40.858241      -73.907932
# 9              Aqueduct Walk      40.858241      -73.907932
# 10             Aqueduct Walk      40.858241      -73.907932
# 11             Aqueduct Walk      40.858241      -73.907932
# 12             Aqueduct Walk      40.858241      -73.907932
# 13             Aqueduct Walk      40.858241      -73.907932
# 14             Aqueduct Walk      40.858241      -73.907932
# 15             Aqueduct Walk      40.858241      -73.907932
# 16             Aqueduct Walk      40.858241      -73.907932
# 17             Aqueduct Walk      40.858241      -73.907932
# 18             Aqueduct Walk      40.858241      -73.907932
# 19             Aqueduct Walk      40.858241      -73.907932
# 20             Aqueduct Walk      40.858241      -73.907932
# 21             Aqueduct Walk      40.858241      -73.907932
# 22             Aqueduct Walk      40.858241      -73.907932
# 23              Astoria Park      40.779017      -73.922184
# 24              Astoria Park      40.779017      -73.922184
# 25              Astoria Park      40.779017      -73.922184
# 26              Astoria Park      40.779017      -73.922184
# 27              Astoria Park      40.779017      -73.922184
# 28              Astoria Park      40.779017      -73.922184
# 29              Astoria Park      40.779017      -73.922184
# ...                      ...            ...             ...
# 2654  Washington Square Park      40.730885      -73.997610
# 2655  Washington Square Park      40.730885      -73.997610
# 2656  Washington Square Park      40.730885      -73.997610
# 2657  Washington Square Park      40.730885      -73.997610
# 2658  Washington Square Park      40.730885      -73.997610
# 2659  Washington Square Park      40.730885      -73.997610
# 2660  Washington Square Park      40.730885      -73.997610
# 2661  Washington Square Park      40.730885      -73.997610
# 2662  Washington Square Park      40.730885      -73.997610
# 2663  Washington Square Park      40.730885      -73.997610
# 2664  Washington Square Park      40.730885      -73.997610
# 2665  Washington Square Park      40.730885      -73.997610
# 2666  Washington Square Park      40.730885      -73.997610
# 2667  Washington Square Park      40.730885      -73.997610
# 2668  Washington Square Park      40.730885      -73.997610
# 2669  Washington Square Park      40.730885      -73.997610
# 2670  Washington Square Park      40.730885      -73.997610
# 2671  Washington Square Park      40.730885      -73.997610
# 2672  Washington Square Park      40.730885      -73.997610
# 2673  Washington Square Park      40.730885      -73.997610
# 2674  Washington Square Park      40.730885      -73.997610
# 2675  Washington Square Park      40.730885      -73.997610
# 2676  Washington Square Park      40.730885      -73.997610
# 2677  Washington Square Park      40.730885      -73.997610
# 2678  Washington Square Park      40.730885      -73.997610
# 2679  Washington Square Park      40.730885      -73.997610
# 2680       Wolfe's Pond Park      40.521063      -74.189263
# 2681       Wolfe's Pond Park      40.521063      -74.189263
# 2682       Wolfe's Pond Park      40.521063      -74.189263
# 2683       Wolfe's Pond Park      40.521063      -74.189263
#
#                                                   Venue  \
# 0                                      Double Dome Park
# 1                     Alley Pond Park Basketball Courts
# 2                                              Insignia
# 3                            Alley Pond Softball Fields
# 4                     Long Island Expressway at Exit 30
# 5                                              Liberato
# 6     Elsa La Reina Del Chicharrón (Elsa The Queen O...
# 7                                      Giovanni's Pizza
# 8                                    Bravo Supermarkets
# 9                                              Wingstop
# 10                                      Accra Resturant
# 11                                             Liberato
# 12                                           Chase Bank
# 13                                       Domino's Pizza
# 14                                          Au Bon Pain
# 15                                  C-Town Supermarkets
# 16                                               Subway
# 17                                           McDonald's
# 18                                        Family Dollar
# 19                                       Fordham Toyota
# 20                                Kennedy fried chicken
# 21                                                  KFC
# 22                                                   BP
# 23                                         Astoria Park
# 24                             Palermo Restaurant & Bar
# 25                            Thai New York Spa & Salon
# 26                                   Astoria Park Track
# 27                                         Agnanti Meze
# 28                                    Astoria Park Pool
# 29                          Whisker's Holistic Pet Care
# ...                                                 ...
# 2654                                        Menkoi Sato
# 2655                                    Doggy Style NYC
# 2656                    Brooklyn Bagel & Coffee Company
# 2657                                        Joe's Pizza
# 2658                                         Liquiteria
# 2659                                        Bar Fortuna
# 2660                                   Pearl Oyster Bar
# 2661                                      Fay Da Bakery
# 2662                                             Popbar
# 2663                                          Manousheh
# 2664                           Porto Rico Importing Co.
# 2665                                CO Bigelow Pharmacy
# 2666                          il Laboratorio del Gelato
# 2667                                            Carbone
# 2668                                  Mercer Playground
# 2669                  Junzi Kitchen (Greenwich Village)
# 2670                                     Amorino Gelato
# 2671                                                Joe
# 2672                           Lifethyme Natural Market
# 2673                                           Le Gigot
# 2674                                    Madman Espresso
# 2675                                               Alta
# 2676                                   Molly's Cupcakes
# 2677                                 La Petite Coquette
# 2678                                              Dante
# 2679                                              Palma
# 2680                                  Wolfe's Pond Park
# 2681                                Prescott Playground
# 2682                          Wolfe's Pond Park Dog Run
# 2683                                     Huguenot Beach
#
#                       Venue ID  Venue Latitude  Venue Longitude  \
# 0     4dceb82dd164679b8d06a92f       40.747824       -73.744686
# 1     4c55f7e619160f470fdf0fb4       40.746997       -73.745041
# 2     4f614744e4b011d850782b65       40.751210       -73.747938
# 3     4dbdbcca0437955ec0547698       40.752045       -73.744697
# 4     4d59bbb424466ea881857a9f       40.750906       -73.749218
# 5     4c9fcdfc8afca09381840d16       40.858525       -73.903902
# 6     4c6c82f56af58cfac5248717       40.858627       -73.903682
# 7     4c54850b4623be9ae52cebf2       40.860383       -73.906661
# 8     4c63360ae1621b8d5a792553       40.860352       -73.906604
# 9     582097ccfa17e5344ac6984f       40.854093       -73.907899
# 10    4c2f8b1b7cc0c9b6a1eaeb9a       40.853871       -73.908421
# 11    4bcf761b41b9ef3b547af8e5       40.853744       -73.907966
# 12    4ba24ffcf964a52048ec37e3       40.854087       -73.907631
# 13    4cdf3bbf78ddf04d6ec29f98       40.854541       -73.907037
# 14    4e5f8bde45dd4656dd97be19       40.858062       -73.912040
# 15    4de514a218505285fcf86aef       40.860358       -73.906657
# 16    4d9a07842bd6f04d88f28b50       40.853887       -73.907285
# 17    4c20227fbd9d9521cd66983f       40.854336       -73.907281
# 18    4de94b99d1648c979649183a       40.859246       -73.903573
# 19    4c3c5b7286ce328f1995ab2d       40.861785       -73.910400
# 20    4d3b79a834ee37048a94839b       40.858687       -73.903577
# 21    4cb7281864998cfa93071ba2       40.853766       -73.907339
# 22    4c327a8f7cc0c9b6bf6bf09a       40.859854       -73.902683
# 23    43222200f964a5209a271fe3       40.777315       -73.923792
# 24    52f59ea2498e015296d4039c       40.776905       -73.921270
# 25    4c4a16b1c668e21e88991ef8       40.777068       -73.921050
# 26    4bbd0fbb8ec3d13acea01b28       40.776723       -73.925833
# 27    4a74bb15f964a52066df1fe3       40.781124       -73.917901
# 28    4a58c9a2f964a520dfb71fe3       40.778754       -73.922453
# 29    4abcf7c8f964a520dd8720e3       40.780746       -73.917097
# ...                        ...             ...              ...
# 2654  5b4fcefc4a7aae002c0878a6       40.731648       -74.001447
# 2655  4d697e58342b8cfad8dac92c       40.732459       -73.994158
# 2656  5b8e66ac234724002c927c4b       40.730913       -73.993259
# 2657  45ebc982f964a52091431fe3       40.730461       -74.001972
# 2658  54b91cda498e5672980990f5       40.733606       -73.999481
# 2659  58018d2b38fa5124660379bd       40.733884       -73.998788
# 2660  3fd66200f964a52093e71ee3       40.731443       -74.002066
# 2661  4f663439e4b0bf101381bb62       40.731102       -74.001620
# 2662  4bb10203f964a52056723ce3       40.730543       -74.001999
# 2663  550af1d0498e5c0bd04229e6       40.729373       -74.001350
# 2664  3fd66200f964a52059e61ee3       40.729483       -74.001722
# 2665  49f9ea7af964a520946d1fe3       40.734049       -73.999368
# 2666  5a319bf82c7eb93dcc6c0b7c       40.732653       -73.993917
# 2667  504b2a9ee4b006c435a465d3       40.727903       -74.000136
# 2668  4b9fd380f964a5202d4237e3       40.727634       -73.996566
# 2669  5b36566f666116002c6b265e       40.728767       -74.000535
# 2670  4de43bb11520b8ceaac8b906       40.732835       -73.993795
# 2671  4388f700f964a520182b1fe3       40.733297       -74.000566
# 2672  3fd66200f964a52015e71ee3       40.733860       -73.999375
# 2673  4abe33aaf964a520f18b20e3       40.731452       -74.001950
# 2674  54fc7f0c498eaf6bec5ba85f       40.732615       -73.993970
# 2675  41abb800f964a520581e1fe3       40.734425       -73.998238
# 2676  4e28648c2271752a4594123e       40.730149       -74.002262
# 2677  4b37b5f7f964a520db4425e3       40.732530       -73.994011
# 2678  556f4ef2498ee60139b28c72       40.728847       -74.001622
# 2679  3fd66200f964a5202de71ee3       40.731313       -74.002409
# 2680  4b125bbff964a5207e8923e3       40.517982       -74.189153
# 2681  501ab6b7f1369c845f8dd960       40.522363       -74.186060
# 2682  4c3fa608d691c9b65b188a0a       40.519888       -74.185123
# 2683  4f00c0a58231bcb704ad6600       40.521988       -74.183781
#
#                  Venue Category  Park_with_cafe
# 0                Baseball Field           False
# 1              Basketball Court           False
# 2                    Steakhouse           False
# 3            Athletics & Sports           False
# 4                  Intersection           False
# 5            Spanish Restaurant           False
# 6            Spanish Restaurant           False
# 7                   Pizza Place           False
# 8                 Grocery Store           False
# 9                   Wings Joint           False
# 10           African Restaurant           False
# 11    Latin American Restaurant           False
# 12                         Bank           False
# 13                  Pizza Place           False
# 14                       Bakery           False
# 15                Grocery Store           False
# 16               Sandwich Place           False
# 17         Fast Food Restaurant           False
# 18               Discount Store           False
# 19              Auto Dealership           False
# 20          Fried Chicken Joint           False
# 21          Fried Chicken Joint           False
# 22                  Gas Station           False
# 23                         Park            True
# 24           Italian Restaurant            True
# 25                   Nail Salon            True
# 26                        Track            True
# 27             Greek Restaurant            True
# 28                         Pool            True
# 29                    Pet Store            True
# ...                         ...             ...
# 2654           Ramen Restaurant            True
# 2655                  Pet Store            True
# 2656                 Bagel Shop            True
# 2657                Pizza Place            True
# 2658                  Juice Bar            True
# 2659                  Speakeasy            True
# 2660         Seafood Restaurant            True
# 2661                     Bakery            True
# 2662             Ice Cream Shop            True
# 2663        Lebanese Restaurant            True
# 2664                Coffee Shop            True
# 2665                   Pharmacy            True
# 2666             Ice Cream Shop            True
# 2667         Italian Restaurant            True
# 2668                 Playground            True
# 2669         Chinese Restaurant            True
# 2670             Ice Cream Shop            True
# 2671                Coffee Shop            True
# 2672          Health Food Store            True
# 2673          French Restaurant            True
# 2674                Coffee Shop            True
# 2675           Tapas Restaurant            True
# 2676               Cupcake Shop            True
# 2677             Lingerie Store            True
# 2678         Italian Restaurant            True
# 2679         Italian Restaurant            True
# 2680                       Park           False
# 2681                 Playground           False
# 2682                    Dog Run           False
# 2683                      Beach           False
#
# [2684 rows x 9 columns]

# %%
df_parks_cafe_not = venues_nearby_all_parks_df.groupby('Park_name')['Park_with_cafe'].any().reset_index()

# %%
mapping_dictionary = dict([(name, idx) for idx, name in enumerate(venues_nearby_all_parks_df['Venue Category'].unique())])

# %%
def is_cafe(string_input):
    return ('Coffee' in string_input) | ('Caf' in string_input)

# %%
venues_nearby_all_parks_df['Is_caffe'] = venues_nearby_all_parks_df['Venue Category'].apply(is_cafe)

# %%
top_rated_venues_caffe = venues_nearby_all_parks_df[['Park_name', 'Venue', 'Rating']][venues_nearby_all_parks_df['Is_caffe']].groupby('Park_name').max()

# %%
top_rated_venues_caffe.sort_values(by='Rating', ascending=False)[:5]
# Out:
#                                        Venue  Rating
# Park_name
# Battery Park                       Starbucks     9.2
# Morningside Park               Up Coffee Co.     8.9
# Starlight Park          Prospect Coffee Shop     8.4
# Eastern Parkway          Jenny Coffe Shop #2     8.2
# Washington Square Park         The Uncommons     8.0

# %%
top5_parks = top_rated_venues_caffe.sort_values(by='Rating', ascending=False)[:5].index.tolist()

# %%
#Let's learn what other best venues are close to the "best performing" caffes

# %%
def top_5_other_venues(list_of_objects):
    tmp_list = sorted(list_of_objects, reverse = True)
    return tmp_list[:5]

# %%
top_rated_venues_not_caffe = venues_nearby_all_parks_df[['Park_name', 'Venue Category', 'Rating']][~venues_nearby_all_parks_df['Is_caffe']].groupby('Park_name').agg(top_5_other_venues).reset_index()

# %%
top_rated_venues_not_caffe[top_rated_venues_not_caffe['Park_name'].apply(lambda x: x in top5_parks)]['Venue Category'].values
# Out:
# array([list(["Women's Store", 'Wine Shop', 'Wine Bar', 'Supplement Shop', 'Steakhouse']),
#        list(['Yoga Studio', 'Wings Joint', 'Vegetarian / Vegan Restaurant', 'Thai Restaurant', 'Sushi Restaurant']),
#        list(['Wine Shop', 'Wine Shop', 'Wine Bar', 'Wine Bar', 'Sports Bar']),
#        list(['Video Game Store', 'Supplement Shop', 'Supermarket', 'Shopping Mall', 'Shoe Store']),
#        list(['Yoga Studio', 'Wine Shop', 'Wine Bar', 'Wine Bar', 'Wine Bar'])],
#       dtype=object)

# %%
#We can see that Women's Store, Yoga Studio and Wine shops/bars are common venues that are close to best performing
#caffes, we need to look for a park which has such amenities, but still doesn't have a coffee shop

# %%
parks_venues = venues_nearby_all_parks_df[~venues_nearby_all_parks_df['Park_with_cafe']].groupby('Park_name')['Venue Category'].apply(list)

# %%
def lookup_venues(list_of_venues):
    count_of_items = 0
    items_to_find = ["Women's Store", 'Wine Shop', 'Yoga Studio', "Wine Bar", 'Supplement Shop']
    for item in list_of_venues:
        if item in items_to_find:
            count_of_items += 1
    return count_of_items

# %%
parks_venues.apply(lambda x: lookup_venues(x)).sort_values(ascending=False)[:3]
# Out:
# Park_name
# Spring Creek Park    3
# Franz Sigel Park     2
# Highbridge Park      1
# Name: Venue Category, dtype: int64

# %%
#Spring Creek Park seems like the best candidate, which has popular amenities, that are similar to the ones, where the
# "best performing" coffee shops are

# %%
parks_df[parks_df['Park_name'] == 'Spring Creek Park'][['Park_name', 'Address','Latitude', 'Longitude']]
# Out:
#              Park_name                                          Address  \
# 411  Spring Creek Park  Vandalia Ave, Gateway Dr, Erskine St, Belt Pkwy
#
#       Latitude  Longitude
# 411  40.651426 -73.874781

# %% [markdown]
# ## Plot park candidates for the coffee shops

# %%
latitude = 40.651426
longitude =  -73.874781
# create map of Toronto using latitude and longitude values
map_NYC_with_caffes= folium.Map(location=[latitude, longitude], zoom_start=14)

# add markers to map
label = '{}, {}'.format('Spring Creek Park', 'Vandalia Ave, Gateway Dr, Erskine St, Belt Pkwy')
label = folium.Popup(label, parse_html=True)
folium.CircleMarker(
    [latitude, longitude],
    radius=5,
    popup=label,
    color='blue',
    fill=True,
    fill_color='blue',
    fill_opacity=0.7).add_to(map_NYC_with_caffes)
map_NYC_with_caffes
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
